# %% [markdown]
# # মডিউল ৬: Functions
# ## ক্লাস ২০: Practice Class
#
# ### 🎯 আজকের লক্ষ্য
# - কাস্টম ফাংশন তৈরির বাস্তবমুখী অনুশীলন
# - Calculator ফাংশন
# - Grade নির্ণয়ের ফাংশন
# - ধারার সমষ্টি নির্ণয়ের ফাংশন তৈরি

# %%
# ১. Calculator Function
def calculator(a, b, operation):
    if operation == "add":
        return a + b
    elif operation == "sub":
        return a - b
    elif operation == "mul":
        return a * b
    elif operation == "div":
        if b == 0:
            return "Error! Zero Division."
        return a / b
    else:
        return "Invalid Operation"

print("যোগ:", calculator(10, 5, "add"))
print("ভাগ (শুন্য দিয়ে):", calculator(10, 0, "div"))

# %%
# ২. Grade Function
def get_grade(marks):
    if marks >= 80: return "A+"
    elif marks >= 70: return "A"
    elif marks >= 60: return "A-"
    elif marks >= 50: return "B"
    elif marks >= 40: return "C"
    elif marks >= 33: return "D"
    else: return "F"

print("৮৫ মার্কস এর গ্রেড:", get_grade(85))

# %%
# ৩. Sum of Series Function (১ থেকে n পর্যন্ত সংখ্যার সমষ্টি)
def sum_series(n):
    total = 0
    for i in range(1, n + 1):
        total += i
    return total

print("১ থেকে ১০০ পর্যন্ত যোগফল:", sum_series(100))

# %% [markdown]
# ### 📝 ক্লাস ২০ — অনুশীলন কাজ
# 1. এমন একটি ফাংশন লেখো যা প্যারামিটার হিসেবে একটি সংখ্যা নেবে এবং সংখ্যাটি **Perfect Number** (আদর্শ সংখ্যা, যার উৎপাদকের যোগফল সংখ্যাটির সমান, যেমন: ৬ = ১+২+৩) কি না তা পরীক্ষা করবে।
